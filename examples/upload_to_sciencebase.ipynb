# %% [markdown]
# # Upload files to Science Base
#
# Here we are going to use `sciencebasepy` to programmatically upload MTH5 files to a parent Science Base page.

# %%
from pathlib import Path
import sciencebasepy as sb
import time

# %% [markdown]
# ## Parent Page
#
# Need to know the parent page to upload to.  This will be the list of numbers and characters at the end of your Science Base web address you were assigned.

# %%
parent_id = "67a3b942d34e63325c2b7229"

# %% [markdown]
# ## Start a Session
#
# First, initiallize a Science Base session.  Now that we no longer have a AD password we need to login differently.  Here we need to get a token to connect to Science Base.
#
# `session.get_token()` will open a web browser.  In the upper right hand corner there will be a profile icon. Click on it and click `Copy API Token`.  You will need to paste it into the next cell.
#
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you are creating a Science Base data release "Prod" mode or production mode don't use any keywords in SbSession().  If you are just downloading data from Science Base you can use SbSession("beta").
# </div>

# %%
session = sb.SbSession() # use sb.SbSession("beta") if just downloading. 
session.get_token()
# Out:
# A browser window/tab should momentarily open with ScienceBase Manager
# Sign in using active directory or login.gov
# Click the user icon in the upper right and select 'Copy API token'
# This copies the token to your clipboard
# Use this value in the add_token function as the token_json parameter

# %% [markdown]
# ### API Token
#
# Paste the copied API Token here.  What you copied will be the full dictionary.

# %%
token = {
    "access_token": "eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJCMWJfZFBNR3BWY09hT253dU0zQThnSGF2Mzd5U1Y0OXJaLUZ2U2gtaXRNIn0.....TWVQvQRrkYYmPapnV4rLMDi-pN7Bp3IzaE_qRMYNMU95RT3PCw_4dWRVFNdakNzrLSNcOmQZ28s-hYed_ktkjAf2sGNzGBX3fZYoXnWtPftTHzAVhdrkMH8nFBmjuiCnbkWNL_3c6AcrWtIyiXFQffpMogQS8NjqukTqKQpq3KJiSPqjFb6WYkIt406jkRJEfoDFxe6Fmz1zIQ06e67AOf7EBZmSXgzHAaRPrQmjlr-pYmMV48cnHjVA77ZIdgOlLns6F1h7KGzNg0uMaQdBalQqpvLQhVC4GKvDbaKOK8oMf0aTzhrVbJm5eHBxE__dattMqNd-puXsFvkqSstPyQ",
    "refresh_token": "eyJhbGciOiJIUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJkMmMyMmZmMy1mZjIxLTQ4NjQtYjJlMS04NTQ1ZWJlNmU0NjkifQ.....Rrs6BUod12bJCHG7Hf8I_6ndXvhd6-QnC-FPFi-QfbA",
}

# %% [markdown]
# ### Add the API Token
# To login add the API token to the session.

# %%
session.add_token(token)

# %%
# be sure you are logged in.
print(f"Is Logged In: {session.is_logged_in()}")
# Out:
# Is Logged In: True

# %% [markdown]
# ## Parent Item
#
# Now we are goint to get the parent item, which returns a JSON file that describes the Science Base page.  You can adjust this to adjust the web page.

# %%
item = session.get_item(parent_id)

# %% [markdown]
# ## Upload MTH5s
#
# We are going to upload the MTH5 files to the parent page, which is different from what we have done in the past and should be easier for the user.  The basics are that we are going to upload the file then append the file to the parent item.
#
# I have all the MTH5 files in one directory, suggest doing the same.  Set the path to that directory.
#
# <div class="alert alert-block alert-warning">
# <b>Warning:</b> Sometimes there are timeouts or something goes wrong with uploading, so we will catch the error and move on to the next file.  So be sure to check the output for MTH5 files that were not uploaded properly.
# </div>

# %%
h5_path = Path(r"c:\\Users\\jpeacock\\OneDrive - DOI\\MTData\\CL2021\\archive")

# %%
for h5_file in list(h5_path.glob("*.h5")):
    if h5_file.name in [d["name"] for d in item["files"]]:
        print(f"Skipping: {h5_file.name} is already uploaded")
        continue
    try:
        item = session.upload_file_to_item(item, h5_file.as_posix(), scrape_file=False)
        print(f"{time.ctime()} Uploaded: {h5_file.name}")
    except Exception as error:
        print(f"{h5_file.name} Error: {error}")
        print(f"Is Logged In: {session.is_logged_in()}")
        item = session.get_item(parent_id)
        continue
# Out:
# Skipping: cl008.h5 is already uploaded
# Skipping: cl016.h5 is already uploaded
# Skipping: cl017.h5 is already uploaded
# Skipping: cl024.h5 is already uploaded
# Skipping: cl028.h5 is already uploaded
# Skipping: cl029.h5 is already uploaded
# Skipping: cl031.h5 is already uploaded
# Skipping: cl032.h5 is already uploaded
# Skipping: cl036.h5 is already uploaded
# Skipping: cl037.h5 is already uploaded
# Skipping: cl043.h5 is already uploaded
# Skipping: cl044.h5 is already uploaded
# Skipping: cl049.h5 is already uploaded
# Skipping: cl051.h5 is already uploaded
# Skipping: cl059.h5 is already uploaded
# cl060.h5 Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Is Logged In: False
# Skipping: cl061.h5 is already uploaded
# Skipping: cl070.h5 is already uploaded
# Skipping: cl071.h5 is already uploaded
# Skipping: cl074.h5 is already uploaded
# Skipping: cl077.h5 is already uploaded
# Skipping: cl078.h5 is already uploaded
# Skipping: cl088.h5 is already uploaded
# Skipping: cl090.h5 is already uploaded
# Skipping: cl099.h5 is already uploaded
# Skipping: cl101.h5 is already uploaded
# Skipping: cl103.h5 is already uploaded
# Skipping: cl104.h5 is already uploaded
# Skipping: cl108.h5 is already uploaded
# Skipping: cl110.h5 is already uploaded
# Skipping: cl111.h5 is already uploaded
# Skipping: cl112.h5 is already uploaded
# Skipping: cl113.h5 is already uploaded
# Skipping: cl126.h5 is already uploaded
# Skipping: cl128.h5 is already uploaded
# Skipping: cl129.h5 is already uploaded
# Skipping: cl140.h5 is already uploaded
# Skipping: cl141.h5 is already uploaded
# Skipping: cl160.h5 is already uploaded
# Skipping: cl161.h5 is already uploaded
# Skipping: cl162.h5 is already uploaded
# Skipping: cl163.h5 is already uploaded
# Skipping: cl200.h5 is already uploaded
# Skipping: cl201.h5 is already uploaded
# Skipping: cl203.h5 is already uploaded
# Skipping: cl204.h5 is already uploaded
# Skipping: cl205.h5 is already uploaded
# Skipping: cl207.h5 is already uploaded
# Skipping: cl208.h5 is already uploaded
# Skipping: cl211.h5 is already uploaded
# Skipping: cl221.h5 is already uploaded
# Skipping: cl230.h5 is already uploaded
# Skipping: cl302.h5 is already uploaded
# Skipping: cl303.h5 is already uploaded
# Skipping: cl304.h5 is already uploaded
# Skipping: cl305.h5 is already uploaded
# Skipping: cl306.h5 is already uploaded
# Skipping: cl3101.h5 is already uploaded
# Skipping: cl3116.h5 is already uploaded
# Skipping: cl3121.h5 is already uploaded
# Skipping: cl3129.h5 is already uploaded
# Skipping: cl321.h5 is already uploaded
# Skipping: cl326.h5 is already uploaded
# Skipping: cl340.h5 is already uploaded
# Skipping: cl341.h5 is already uploaded
# Skipping: cl355.h5 is already uploaded
# Skipping: cl362.h5 is already uploaded
# Skipping: cl381.h5 is already uploaded
# Skipping: cl393.h5 is already uploaded
# Skipping: cl394.h5 is already uploaded
# Skipping: cl395.h5 is already uploaded
# Skipping: cl396.h5 is already uploaded
# Skipping: cl397.h5 is already uploaded
# Skipping: cl407.h5 is already uploaded
# Skipping: cl408.h5 is already uploaded
# Skipping: cl409.h5 is already uploaded
# Skipping: cl431.h5 is already uploaded
# Skipping: cl433.h5 is already uploaded
# Skipping: cl434.h5 is already uploaded
# Skipping: cl435.h5 is already uploaded
# Skipping: cl436.h5 is already uploaded
# Skipping: cl455.h5 is already uploaded
# Skipping: cl461.h5 is already uploaded
# Skipping: cl463.h5 is already uploaded
# Skipping: cl471.h5 is already uploaded
# Skipping: cl472.h5 is already uploaded
# Skipping: cl473.h5 is already uploaded
# Skipping: cl478.h5 is already uploaded
# Skipping: cl479.h5 is already uploaded
# Skipping: cl484.h5 is already uploaded
# Skipping: cl485.h5 is already uploaded
# Skipping: cl486.h5 is already uploaded
# Skipping: cl491.h5 is already uploaded

# %% [markdown]
# ### Check for failed files
#
# If the log got deleted or you didn't run the previous cell, check for files that are not on the parent page.

# %%
fns = [d["name"] for d in item["files"]] 
for a in h5_path.glob("*.h5"):
    if a.name not in fns:
        print(a.name)
# Out:
# cl060.h5

# %% [markdown]
# ## Reorder File List
#
# For organization, we will reorder the files alphanumerically, otherwise they are ordered in the order they were uploaded.

# %%
fns = [d["name"] for d in item["files"]]
print(fns)
# Out:
# ['cl008.h5', 'cl016.h5', 'cl017.h5', 'cl029.h5', 'cl031.h5', 'cl024.h5', 'cl028.h5', 'cl032.h5', 'cl036.h5', 'cl037.h5', 'cl043.h5', 'cl044.h5', 'cl049.h5', 'cl051.h5', 'cl059.h5', 'cl061.h5', 'cl070.h5', 'cl071.h5', 'cl074.h5', 'cl077.h5', 'cl088.h5', 'cl090.h5', 'cl099.h5', 'cl101.h5', 'cl103.h5', 'cl104.h5', 'cl108.h5', 'cl111.h5', 'cl112.h5', 'cl113.h5', 'cl126.h5', 'cl128.h5', 'cl129.h5', 'cl140.h5', 'cl141.h5', 'cl160.h5', 'cl161.h5', 'cl162.h5', 'cl163.h5', 'cl200.h5', 'cl201.h5', 'cl203.h5', 'cl204.h5', 'cl205.h5', 'cl207.h5', 'cl208.h5', 'cl211.h5', 'cl221.h5', 'cl230.h5', 'cl302.h5', 'cl303.h5', 'cl304.h5', 'cl305.h5', 'cl306.h5', 'cl3101.h5', 'cl3116.h5', 'cl3121.h5', 'cl3129.h5', 'cl321.h5', 'cl326.h5', 'cl340.h5', 'cl341.h5', 'cl355.h5', 'cl362.h5', 'cl381.h5', 'cl393.h5', 'cl394.h5', 'cl395.h5', 'cl396.h5', 'cl397.h5', 'cl407.h5', 'cl408.h5', 'cl409.h5', 'cl431.h5', 'cl433.h5', 'cl434.h5', 'cl436.h5', 'cl455.h5', 'cl461.h5', 'cl463.h5', 'cl471.h5', 'cl472.h5', 'cl473.h5', 'cl478.h5', 'cl479.h5', 'cl484.h5', 'cl485.h5', 'cl486.h5', 'cl491.h5', 'cl078.h5', 'cl110.h5', 'cl435.h5', 'cl060A.h5', 'clearlake_2022_metadata.xml', 'clearlake2022_mt_edis_and_pngs.zip']

# %%
initial_files = []
h5_files = []
for fn in fns:
    if fn.endswith(".xml"):
        initial_files.append(fn)
    elif fn.endswith(".zip"):
        initial_files.append(fn)
    else:
        h5_files.append(fn)

ordered_fns = initial_files + sorted(h5_files)
for fn in ordered_fns:
    print(fn)
# Out:
# clearlake_2022_metadata.xml
# clearlake2022_mt_edis_and_pngs.zip
# cl008.h5
# cl016.h5
# cl017.h5
# cl024.h5
# cl028.h5
# cl029.h5
# cl031.h5
# cl032.h5
# cl036.h5
# cl037.h5
# cl043.h5
# cl044.h5
# cl049.h5
# cl051.h5
# cl059.h5
# cl060A.h5
# cl061.h5
# cl070.h5
# cl071.h5
# cl074.h5
# cl077.h5
# cl078.h5
# cl088.h5
# cl090.h5
# cl099.h5
# cl101.h5
# cl103.h5
# cl104.h5
# cl108.h5
# cl110.h5
# cl111.h5
# cl112.h5
# cl113.h5
# cl126.h5
# cl128.h5
# cl129.h5
# cl140.h5
# cl141.h5
# cl160.h5
# cl161.h5
# cl162.h5
# cl163.h5
# cl200.h5
# cl201.h5
# cl203.h5
# cl204.h5
# cl205.h5
# cl207.h5
# cl208.h5
# cl211.h5
# cl221.h5
# cl230.h5
# cl302.h5
# cl303.h5
# cl304.h5
# cl305.h5
# cl306.h5
# cl3101.h5
# cl3116.h5
# cl3121.h5
# cl3129.h5
# cl321.h5
# cl326.h5
# cl340.h5
# cl341.h5
# cl355.h5
# cl362.h5
# cl381.h5
# cl393.h5
# cl394.h5
# cl395.h5
# cl396.h5
# cl397.h5
# cl407.h5
# cl408.h5
# cl409.h5
# cl431.h5
# cl433.h5
# cl434.h5
# cl435.h5
# cl436.h5
# cl455.h5
# cl461.h5
# cl463.h5
# cl471.h5
# cl472.h5
# cl473.h5
# cl478.h5
# cl479.h5
# cl484.h5
# cl485.h5
# cl486.h5
# cl491.h5

# %% [markdown]
# ## Reorder file list by name

# %%
new_file_list = []

for fn in ordered_fns:
    for file_item in item["files"]:
        if file_item["name"] == fn:
            new_file_list.append(file_item)
            break

item["files"] = new_file_list
for d in item["files"]:
    print(d["name"])
# Out:
# clearlake_2022_metadata.xml
# clearlake2022_mt_edis_and_pngs.zip
# cl008.h5
# cl016.h5
# cl017.h5
# cl024.h5
# cl028.h5
# cl029.h5
# cl031.h5
# cl032.h5
# cl036.h5
# cl037.h5
# cl043.h5
# cl044.h5
# cl049.h5
# cl051.h5
# cl059.h5
# cl060A.h5
# cl061.h5
# cl070.h5
# cl071.h5
# cl074.h5
# cl077.h5
# cl078.h5
# cl088.h5
# cl090.h5
# cl099.h5
# cl101.h5
# cl103.h5
# cl104.h5
# cl108.h5
# cl110.h5
# cl111.h5
# cl112.h5
# cl113.h5
# cl126.h5
# cl128.h5
# cl129.h5
# cl140.h5
# cl141.h5
# cl160.h5
# cl161.h5
# cl162.h5
# cl163.h5
# cl200.h5
# cl201.h5
# cl203.h5
# cl204.h5
# cl205.h5
# cl207.h5
# cl208.h5
# cl211.h5
# cl221.h5
# cl230.h5
# cl302.h5
# cl303.h5
# cl304.h5
# cl305.h5
# cl306.h5
# cl3101.h5
# cl3116.h5
# cl3121.h5
# cl3129.h5
# cl321.h5
# cl326.h5
# cl340.h5
# cl341.h5
# cl355.h5
# cl362.h5
# cl381.h5
# cl393.h5
# cl394.h5
# cl395.h5
# cl396.h5
# cl397.h5
# cl407.h5
# cl408.h5
# cl409.h5
# cl431.h5
# cl433.h5
# cl434.h5
# cl435.h5
# cl436.h5
# cl455.h5
# cl461.h5
# cl463.h5
# cl471.h5
# cl472.h5
# cl473.h5
# cl478.h5
# cl479.h5
# cl484.h5
# cl485.h5
# cl486.h5
# cl491.h5

# %%
session.update_item({"id": parent_id, "files": new_file_list})
# Out:
# {'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/67a3b942d34e63325c2b7229'},
#  'relatedItems': {'link': {'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=67a3b942d34e63325c2b7229',
#    'rel': 'related'}},
#  'id': '67a3b942d34e63325c2b7229',
#  'identifiers': [{'type': 'IPDS',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'key': 'IP-175657'},
#   {'type': 'DOI',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'key': 'doi:10.5066/P14KAQ3M'},
#   {'type': 'USGS_ScienceCenter',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'key': 'Geology, Minerals, Energy, and Geophysics Science Center'},
#   {'type': 'USGS_MissionArea',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'key': 'Natural Hazards'},
#   {'type': 'USGS_keywords',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'key': 'Energy Resources, Geophysics, Mineral Resources, Volcanology'}],
#  'title': 'Magnetotelluric data from the Clear Lake Region, Northern California',
#  'summary': "The Clear Lake Volcanic Field (CLVF) in northern California is a young (2 Ma-0.008 Ma) volcanic system that could pose hazardous upon eruption. Magnetotellurics (MT) is a passive electromagnetic geophysical method that measures subsurface electrical resistivity by recording the Earth's electrical response to natural time varying magnetic fields. To further understand the magmatic system of the CLVF MT data were collected with the end goal of producing a 3D subsurface electrical resistivity model. MT data were collected in multiple field campaigns between 2021 and 2022 on both public and private lands. Included in this data release is an HDF5 file per MT station that includes time-series data for each run, all runs combined and downsampled [...]",
#  'body': "The Clear Lake Volcanic Field (CLVF) in northern California is a young (2 Ma-0.008 Ma) volcanic system that could pose hazardous upon eruption. Magnetotellurics (MT) is a passive electromagnetic geophysical method that measures subsurface electrical resistivity by recording the Earth's electrical response to natural time varying magnetic fields. To further understand the magmatic system of the CLVF MT data were collected with the end goal of producing a 3D subsurface electrical resistivity model. MT data were collected in multiple field campaigns between 2021 and 2022 on both public and private lands. Included in this data release is an HDF5 file per MT station that includes time-series data for each run, all runs combined and downsampled to 1 sample per second, and the estimated transfer function. These are formatted as MTH5 files (Peacock et al., 2022, https://doi.org/10.1016/j.cageo.2022.105102). All MT transfer functions are included in a ZIP file in EDI format, and an image of each transfer function is included in a ZIP file.<br>\n&nbsp;\n<div>This data product contains magnetotelluric (MT) transfer functions (TFs), which define the frequency dependent linear relations between components of electromagnetic (EM) field variations measured at a single site. Two types of TFs are provided for most sites, impedance data relating horizontal electric and magnetic fields, and tipper data, relating vertical and horizontal magnetic fields. All of the TFs provide input data for subsequent MT inversion and interpretation. They are estimated from the raw EM time series by (a) Fourier transforming data in a series of short overlapping time windows, and (b) applying robust regression methods to calculate TFs from the resulting spectral field estimates. For remote reference processing, data from one or more synchronously recording sites are used for more effective signal/noise separation. The supplied TFs are calculated for a range of periods and include an estimation error covariances.</div>\n\n<div>&nbsp;</div>\n\n<div>To interact with a MTH5 file, an open-source Python package is available `mth5`.&nbsp; It can be installed through PyPi or Conda. Visit https://mth5.readthedocs.io/en/latest/index.html for more details. Or any programming language that can read an HDF5 works.</div>\n\n<div>&nbsp;&nbsp;</div>\n\n<div>To progrommatically download files from Science Base, a user can use an open-source Python package `sciencebasepy`. For more details visit https://github.com/DOI-USGS/sciencebasepy.</div>\n\n<div>&nbsp;</div>\n\n<div>References relevant to this release include:&nbsp;</div>\n\n<div>&nbsp;</div>\n\n<div>&nbsp; &nbsp; &nbsp; Wight, D., 1991, MT/EMAP Data Interchange Standard, The Society of Exploration Geophysicists, accessed January 19, 2021, at&nbsp; https://www.seg.org/Portals/0/SEG/News%20and%20Resources/Technical%20Standards/seg_mt_emap_1987.pdf.&nbsp;</div>\n\n<div>&nbsp;</div>\n\n<div>&nbsp; &nbsp; &nbsp; Peacock, J. R., Kappler, K., Ronan, T., Heagy, L., Kelbert, A., Frassetto, A. (2022) MTH5: An archive and exchangeable data format for magnetotelluric time series data, Computers &amp;amp; Geoscience, 162, doi:10.1016/j.cageo.2022.105102</div>\n",
#  'citation': 'Peacock, J. R., Mitchell, M. A., Burgess, S. D., (2025) Magnetotelluric data from the Clear Lake Region, Northern California, U.S. Geological Survey data release, https//:doi.org/10.5066/P14KAQ3M.',
#  'purpose': 'The purpose of this data release is provide MT station locations, time-series data, and processed transfer functions to the public.',
#  'provenance': {'dateCreated': '2025-02-05T19:17:22Z',
#   'lastUpdated': '2025-03-13T20:54:16Z',
#   'lastUpdatedBy': 'jpeacock@usgs.gov',
#   'createdBy': 'sbdr_app'},
#  'maintenanceUpdateFrequency': 'As needed',
#  'hasChildren': False,
#  'parentId': '5873af5ee4b0a829a31e312e',
#  'contacts': [{'name': 'Jared Peacock',
#    'type': 'Point of Contact',
#    'contactType': 'person',
#    'email': 'jpeacock@usgs.gov',
#    'jobTitle': 'Research Geophysicist',
#    'organization': {'displayText': 'U.S. Geological Survey'},
#    'primaryLocation': {'officePhone': '650-439-2833',
#     'faxPhone': 'PI FAX number',
#     'streetAddress': {},
#     'mailAddress': {'line1': '350 N. Akron',
#      'city': 'Moffett Field',
#      'state': 'CA',
#      'zip': '93025',
#      'country': 'USA'}}},
#   {'name': 'U.S. Geological Survey',
#    'type': 'Point of Contact',
#    'contactType': 'organization',
#    'email': 'jpeacock@usgs.gov',
#    'jobTitle': 'Research Geophysicist',
#    'organization': {},
#    'primaryLocation': {'officePhone': '650-439-2833',
#     'faxPhone': 'PI FAX number',
#     'streetAddress': {},
#     'mailAddress': {'line1': '350 N. Akron',
#      'city': 'Moffett Field',
#      'state': 'CA',
#      'zip': '93025',
#      'country': 'USA'}}},
#   {'name': 'Jared R Peacock',
#    'oldPartyId': 62618,
#    'type': 'Originator',
#    'contactType': 'person',
#    'onlineResource': 'https://usgs.gov/staff-profiles/jared-peacock',
#    'email': 'jpeacock@usgs.gov',
#    'active': True,
#    'jobTitle': 'Supvy Research Geophysicist',
#    'firstName': 'Jared',
#    'middleName': 'R',
#    'lastName': 'Peacock',
#    'organization': {},
#    'primaryLocation': {'officePhone': '6503294833',
#     'streetAddress': {'line1': '350 North Akron Road',
#      'city': 'Moffett Field',
#      'state': 'CA',
#      'zip': '94035',
#      'country': 'US'},
#     'mailAddress': {'line1': '345 Middlefield Rd',
#      'mailStopCode': '989',
#      'state': 'Menlo Park',
#      'zip': 'CA 94025',
#      'country': 'US'}},
#    'orcId': '0000-0002-0439-0224'},
#   {'name': 'Micheal A. Mitchell',
#    'type': 'Originator',
#    'organization': {},
#    'primaryLocation': {'streetAddress': {}, 'mailAddress': {}}},
#   {'name': 'Seth D Burgess',
#    'oldPartyId': 66130,
#    'type': 'Originator',
#    'contactType': 'person',
#    'onlineResource': 'https://usgs.gov/staff-profiles/seth-burgess',
#    'email': 'sburgess@usgs.gov',
#    'active': True,
#    'jobTitle': 'Research Geologist',
#    'firstName': 'Seth',
#    'middleName': 'D',
#    'lastName': 'Burgess',
#    'organization': {},
#    'primaryLocation': {'officePhone': '6503295220',
#     'streetAddress': {'line1': '345 Middlefield Road',
#      'city': 'Menlo Park',
#      'state': 'CA',
#      'zip': '94025',
#      'country': 'US'},
#     'mailAddress': {'line1': '345 Middlefield Road',
#      'line2': 'Mail Stop 910',
#      'mailStopCode': '910',
#      'city': 'Menlo Park',
#      'state': 'CA',
#      'zip': '94025',
#      'country': 'US'}},
#    'orcId': '0000-0002-4238-3797'},
#   {'name': 'Jared Peacock',
#    'type': 'Metadata Contact',
#    'contactType': 'person',
#    'email': 'gs_gmegsc_dm_team@usgs.gov',
#    'jobTitle': 'Research Geophysicist',
#    'organization': {'displayText': 'U.S. Geological Survey'},
#    'primaryLocation': {'officePhone': '650-439-2833',
#     'faxPhone': 'PI FAX number',
#     'streetAddress': {},
#     'mailAddress': {'line1': '350 N. Akron',
#      'city': 'Moffett Field',
#      'state': 'CA',
#      'zip': '93025',
#      'country': 'USA'}}},
#   {'name': 'U.S. Geological Survey',
#    'type': 'Metadata Contact',
#    'contactType': 'organization',
#    'email': 'gs_gmegsc_dm_team@usgs.gov',
#    'jobTitle': 'Research Geophysicist',
#    'organization': {},
#    'primaryLocation': {'officePhone': '650-439-2833',
#     'faxPhone': 'PI FAX number',
#     'streetAddress': {},
#     'mailAddress': {'line1': '350 N. Akron',
#      'city': 'Moffett Field',
#      'state': 'CA',
#      'zip': '93025',
#      'country': 'USA'}}},
#   {'name': 'GS ScienceBase',
#    'type': 'Distributor',
#    'contactType': 'person',
#    'email': 'sciencebase@usgs.gov',
#    'organization': {'displayText': 'U.S. Geological Survey'},
#    'primaryLocation': {'officePhone': '1-888-275-8747',
#     'streetAddress': {},
#     'mailAddress': {'line1': 'Denver Federal Center, Building 810, Mail Stop 302',
#      'city': 'Denver',
#      'state': 'CO',
#      'zip': '80225',
#      'country': 'United States'}}},
#   {'name': 'U.S. Geological Survey',
#    'type': 'Distributor',
#    'contactType': 'organization',
#    'email': 'sciencebase@usgs.gov',
#    'organization': {},
#    'primaryLocation': {'officePhone': '1-888-275-8747',
#     'streetAddress': {},
#     'mailAddress': {'line1': 'Denver Federal Center, Building 810, Mail Stop 302',
#      'city': 'Denver',
#      'state': 'CO',
#      'zip': '80225',
#      'country': 'United States'}}},
#   {'name': 'Volcano Hazards Program',
#    'oldPartyId': 64246,
#    'type': 'Data Owner',
#    'contactType': 'organization',
#    'active': True,
#    'organization': {},
#    'primaryLocation': {'streetAddress': {}, 'mailAddress': {}}}],
#  'browseCategories': ['Data Release - In Progress', 'Data'],
#  'browseTypes': ['Shapefile',
#   'Downloadable',
#   'Map Service',
#   'OGC WMS Layer',
#   'OGC WFS Layer'],
#  'systemTypes': ['Downloadable', 'Mappable'],
#  'tags': [{'type': 'Theme',
#    'scheme': 'ISO 19115 Topic Category',
#    'name': 'geoscientificInformation'},
#   {'type': 'Theme', 'scheme': 'None', 'name': 'magnetotellurics'},
#   {'type': 'Theme', 'scheme': 'None', 'name': 'MT'},
#   {'type': 'Theme', 'scheme': 'None', 'name': 'time series'},
#   {'type': 'Theme', 'scheme': 'None', 'name': 'impedance'},
#   {'type': 'Theme', 'scheme': 'None', 'name': 'apparent resistivity'},
#   {'type': 'Theme', 'scheme': 'None', 'name': 'phase'},
#   {'type': 'Theme', 'scheme': 'None', 'name': 'tipper'},
#   {'type': 'Theme', 'scheme': 'None', 'name': 'conductivity'},
#   {'type': 'Theme',
#    'scheme': 'USGS Thesaurus',
#    'name': 'magnetotelluric surveying'},
#   {'type': 'Theme',
#    'scheme': 'USGS Thesaurus',
#    'name': 'magnetic field (earth)'},
#   {'type': 'Theme', 'scheme': 'USGS Thesaurus', 'name': 'geophysics'},
#   {'type': 'Theme',
#    'scheme': 'USGS Thesaurus',
#    'name': 'electromagnetic surveying'},
#   {'type': 'Theme', 'scheme': 'USGS Thesaurus', 'name': 'geologic structure'},
#   {'type': 'Theme', 'scheme': 'USGS Thesaurus', 'name': 'tectonics'},
#   {'type': 'Theme', 'scheme': 'USGS Thesaurus', 'name': 'exploration'},
#   {'type': 'Place',
#    'scheme': 'Geographic Names Information System (GNIS)',
#    'name': 'Clearlake'},
#   {'type': 'Place',
#    'scheme': 'Geographic Names Information System (GNIS)',
#    'name': 'Lakeport'},
#   {'type': 'Place', 'scheme': 'Common Geographic Areas', 'name': 'California'},
#   {'type': 'Place',
#    'scheme': 'Common Geographic Areas',
#    'name': 'Lake County'},
#   {'type': 'Place',
#    'scheme': 'Common Geographic Areas',
#    'name': 'Sonoma County'},
#   {'type': 'Place',
#    'scheme': 'Common Geographic Areas',
#    'name': 'Mendocino County'},
#   {'type': 'Place',
#    'scheme': 'Common Geographic Areas',
#    'name': 'Colusa County'},
#   {'type': 'Place', 'scheme': 'None', 'name': 'Clear Lake Volcanic Field'}],
#  'dates': [{'type': 'Publication',
#    'dateString': '2025-04-01',
#    'label': 'Publication Date'},
#   {'type': 'Start', 'dateString': '2021-04-27', 'label': ''},
#   {'type': 'End', 'dateString': '2022-11-10', 'label': ''}],
#  'spatial': {'boundingBox': {'minX': -123.2005,
#    'maxX': -122.3578,
#    'minY': 38.549,
#    'maxY': 39.3216}},
#  'facets': [{'boundingBox': {'minY': 38.54896314505231,
#     'minX': -123.2005100144781,
#     'maxY': 39.32160667033032,
#     'maxX': -122.35778844872227},
#    'name': 'cl2022_mt_stations',
#    'files': [{'cuid': None,
#      'key': None,
#      'bucket': None,
#      'published': None,
#      'node': None,
#      'name': 'cl2022_mt_stations.cpg',
#      'title': '',
#      'contentType': 'text/plain',
#      'contentEncoding': None,
#      'pathOnDisk': '__disk__f9/9a/76/f99a760fc2335f14979af2b338171cc578e2d13a',
#      'processed': False,
#      'processToken': None,
#      'imageWidth': None,
#      'imageHeight': None,
#      'size': 5,
#      'dateUploaded': '2025-03-13T20:25:51Z',
#      'uploadedBy': 'jpeacock@usgs.gov',
#      'originalMetadata': False,
#      'useForPreview': False,
#      'movedToS3': None,
#      's3Object': None,
#      'checksum': {'value': 'ae3b3df9970b49b6523e608759bc957d', 'type': 'MD5'},
#      'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__f9%2F9a%2F76%2Ff99a760fc2335f14979af2b338171cc578e2d13a',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__f9%2F9a%2F76%2Ff99a760fc2335f14979af2b338171cc578e2d13a',
#      'viewUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__f9%2F9a%2F76%2Ff99a760fc2335f14979af2b338171cc578e2d13a&allowOpen=true'},
#     {'cuid': None,
#      'key': None,
#      'bucket': None,
#      'published': None,
#      'node': None,
#      'name': 'cl2022_mt_stations.dbf',
#      'title': '',
#      'contentType': 'text/plain',
#      'contentEncoding': None,
#      'pathOnDisk': '__disk__48/43/b6/4843b6dda37642e40367ac6736cf7521bff73ffc',
#      'processed': False,
#      'processToken': None,
#      'imageWidth': None,
#      'imageHeight': None,
#      'size': 49679,
#      'dateUploaded': '2025-03-13T20:25:49Z',
#      'uploadedBy': 'jpeacock@usgs.gov',
#      'originalMetadata': False,
#      'useForPreview': False,
#      'movedToS3': None,
#      's3Object': None,
#      'checksum': {'value': '0d4e4e9fe154eb07fdebe3599310fd73', 'type': 'MD5'},
#      'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__48%2F43%2Fb6%2F4843b6dda37642e40367ac6736cf7521bff73ffc',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__48%2F43%2Fb6%2F4843b6dda37642e40367ac6736cf7521bff73ffc',
#      'viewUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__48%2F43%2Fb6%2F4843b6dda37642e40367ac6736cf7521bff73ffc&allowOpen=true'},
#     {'cuid': None,
#      'key': None,
#      'bucket': None,
#      'published': None,
#      'node': None,
#      'name': 'cl2022_mt_stations.prj',
#      'title': '',
#      'contentType': 'text/plain',
#      'contentEncoding': None,
#      'pathOnDisk': '__disk__1c/f4/88/1cf488e6e7237180470211d18bbfcbff1a57d270',
#      'processed': False,
#      'processToken': None,
#      'imageWidth': None,
#      'imageHeight': None,
#      'size': 145,
#      'dateUploaded': '2025-03-13T20:25:49Z',
#      'uploadedBy': 'jpeacock@usgs.gov',
#      'originalMetadata': False,
#      'useForPreview': False,
#      'movedToS3': None,
#      's3Object': None,
#      'checksum': {'value': 'c742bee3d4edfc2948a2ad08de1790a5', 'type': 'MD5'},
#      'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__1c%2Ff4%2F88%2F1cf488e6e7237180470211d18bbfcbff1a57d270',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__1c%2Ff4%2F88%2F1cf488e6e7237180470211d18bbfcbff1a57d270',
#      'viewUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__1c%2Ff4%2F88%2F1cf488e6e7237180470211d18bbfcbff1a57d270&allowOpen=true'},
#     {'cuid': None,
#      'key': None,
#      'bucket': None,
#      'published': None,
#      'node': None,
#      'name': 'cl2022_mt_stations.shp',
#      'title': '',
#      'contentType': 'x-gis/x-shapefile',
#      'contentEncoding': None,
#      'pathOnDisk': '__disk__17/11/3a/17113ac65ff37d1e6f5fe7604df18ab54d9046da',
#      'processed': False,
#      'processToken': None,
#      'imageWidth': None,
#      'imageHeight': None,
#      'size': 2704,
#      'dateUploaded': '2025-03-13T20:25:49Z',
#      'uploadedBy': 'jpeacock@usgs.gov',
#      'originalMetadata': False,
#      'useForPreview': False,
#      'movedToS3': None,
#      's3Object': None,
#      'checksum': {'value': '23044ab359bcec490f045f51c05a65ec', 'type': 'MD5'},
#      'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__17%2F11%2F3a%2F17113ac65ff37d1e6f5fe7604df18ab54d9046da',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__17%2F11%2F3a%2F17113ac65ff37d1e6f5fe7604df18ab54d9046da'},
#     {'cuid': None,
#      'key': None,
#      'bucket': None,
#      'published': None,
#      'node': None,
#      'name': 'cl2022_mt_stations.shx',
#      'title': '',
#      'contentType': 'x-gis/x-shapefile',
#      'contentEncoding': None,
#      'pathOnDisk': '__disk__0f/18/34/0f1834169970e9ffe2dc294eafac37839e173142',
#      'processed': False,
#      'processToken': None,
#      'imageWidth': None,
#      'imageHeight': None,
#      'size': 844,
#      'dateUploaded': '2025-03-13T20:25:49Z',
#      'uploadedBy': 'jpeacock@usgs.gov',
#      'originalMetadata': False,
#      'useForPreview': False,
#      'movedToS3': None,
#      's3Object': None,
#      'checksum': {'value': '6598730fc44ca90c096cb77dea1321e0', 'type': 'MD5'},
#      'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__0f%2F18%2F34%2F0f1834169970e9ffe2dc294eafac37839e173142',
#      'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__0f%2F18%2F34%2F0f1834169970e9ffe2dc294eafac37839e173142'}],
#    'nativeCrs': 'EPSG:4326',
#    'geometryType': 'Point',
#    'className': 'gov.sciencebase.catalog.item.facet.ShapefileFacet',
#    'facetName': 'Shapefile'}],
#  'files': [{'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'clearlake_2022_metadata.xml',
#    'title': '',
#    'contentType': 'application/fgdc+xml',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__8f/39/b4/8f39b4c4f7d74cc327320a0e04fdda1519f440f1',
#    'processed': False,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 22269,
#    'dateUploaded': '2025-03-13T20:22:09Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': True,
#    'useForPreview': False,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'dcd2e1866a871f8da1e7595ae78e87b7', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__8f%2F39%2Fb4%2F8f39b4c4f7d74cc327320a0e04fdda1519f440f1',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__8f%2F39%2Fb4%2F8f39b4c4f7d74cc327320a0e04fdda1519f440f1',
#    'viewUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__8f%2F39%2Fb4%2F8f39b4c4f7d74cc327320a0e04fdda1519f440f1&allowOpen=true',
#    'metadataHtmlViewUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__8f%2F39%2Fb4%2F8f39b4c4f7d74cc327320a0e04fdda1519f440f1&transform=1'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'clearlake2022_mt_edis_and_pngs.zip',
#    'title': 'MT EDI files and PNG images of each transfer function ',
#    'contentType': 'application/zip',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__9a/a0/1f/9aa01f49543a8d35b0ca560e05585918b76993a0',
#    'processed': False,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 24411347,
#    'dateUploaded': '2025-03-13T20:30:13Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': False,
#    'useForPreview': False,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '58e5fc2ebf9175110599614ff9421f14', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__9a%2Fa0%2F1f%2F9aa01f49543a8d35b0ca560e05585918b76993a0',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__9a%2Fa0%2F1f%2F9aa01f49543a8d35b0ca560e05585918b76993a0'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl008.h5',
#    'title': '',
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__c0/b1/ea/c0b1eae3433f8590b8670a3c20f84f95817eb19b',
#    'processed': False,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 605502793,
#    'dateUploaded': '2025-03-03T23:52:05Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': False,
#    'useForPreview': False,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'a381afb86c568611f47d7a05f1a4e982', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__c0%2Fb1%2Fea%2Fc0b1eae3433f8590b8670a3c20f84f95817eb19b',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__c0%2Fb1%2Fea%2Fc0b1eae3433f8590b8670a3c20f84f95817eb19b'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl016.h5',
#    'title': '',
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__78/63/f9/7863f9c75bdaa119adba4e93dcb41972adc16107',
#    'processed': False,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 590301110,
#    'dateUploaded': '2025-03-04T21:43:36Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': False,
#    'useForPreview': False,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'aa8900b8c7cf6f468b037da5d3076c84', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__78%2F63%2Ff9%2F7863f9c75bdaa119adba4e93dcb41972adc16107',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__78%2F63%2Ff9%2F7863f9c75bdaa119adba4e93dcb41972adc16107'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl017.h5',
#    'title': '',
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__fe/13/30/fe13303f65b1d916100863fa1d01c930210c8091',
#    'processed': False,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 599622012,
#    'dateUploaded': '2025-03-04T21:43:46Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': False,
#    'useForPreview': False,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '02062fd9ea6d812a79e59e6cecbc4730', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__fe%2F13%2F30%2Ffe13303f65b1d916100863fa1d01c930210c8091',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__fe%2F13%2F30%2Ffe13303f65b1d916100863fa1d01c930210c8091'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl024.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__2f/11/e0/2f11e069c16d629b2507cdee4bbd187a704b710e',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 460252533,
#    'dateUploaded': '2025-03-04T22:25:35Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'fb8ef938e5094b2ac91936b5119219da', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__2f%2F11%2Fe0%2F2f11e069c16d629b2507cdee4bbd187a704b710e',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__2f%2F11%2Fe0%2F2f11e069c16d629b2507cdee4bbd187a704b710e'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl028.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__7b/84/5e/7b845ecbf28b8c30340565694ea3c29eb602b81a',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 478801684,
#    'dateUploaded': '2025-03-04T22:27:48Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '5f97be19fc2a042a446427a319ca26de', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__7b%2F84%2F5e%2F7b845ecbf28b8c30340565694ea3c29eb602b81a',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__7b%2F84%2F5e%2F7b845ecbf28b8c30340565694ea3c29eb602b81a'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl029.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__ca/27/79/ca277945bdf7a33ed93d6023857817dd8cd92bde',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 471061507,
#    'dateUploaded': '2025-03-04T22:03:52Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '698824e3b7893d5fd48dc37016c99bed', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__ca%2F27%2F79%2Fca277945bdf7a33ed93d6023857817dd8cd92bde',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__ca%2F27%2F79%2Fca277945bdf7a33ed93d6023857817dd8cd92bde'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl031.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__32/f0/3f/32f03f24ae27843288fea7e17f2d52eb20906bbd',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 528430178,
#    'dateUploaded': '2025-03-04T22:17:40Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '88b47d665fe88649115d5bdd0b00939f', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__32%2Ff0%2F3f%2F32f03f24ae27843288fea7e17f2d52eb20906bbd',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__32%2Ff0%2F3f%2F32f03f24ae27843288fea7e17f2d52eb20906bbd'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl032.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__2c/a8/77/2ca877838c3b5904cce446abd50bba2ae11bb7ed',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 489638058,
#    'dateUploaded': '2025-03-04T22:30:16Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '9b733248fe9fef2d2a1e2e0a85f07345', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__2c%2Fa8%2F77%2F2ca877838c3b5904cce446abd50bba2ae11bb7ed',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__2c%2Fa8%2F77%2F2ca877838c3b5904cce446abd50bba2ae11bb7ed'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl036.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__fe/e3/72/fee3721680c13b41aa250d1e8fa857f452548e39',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 443177813,
#    'dateUploaded': '2025-03-04T22:32:16Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'd8e017ce264fd38e63a345e22e93c3a0', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__fe%2Fe3%2F72%2Ffee3721680c13b41aa250d1e8fa857f452548e39',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__fe%2Fe3%2F72%2Ffee3721680c13b41aa250d1e8fa857f452548e39'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl037.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__77/46/72/77467286169c6c212cb9d1441f950c1e48dcd644',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 350268247,
#    'dateUploaded': '2025-03-04T22:33:48Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'f8ca3562a71dc88950899b578e4e8b89', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__77%2F46%2F72%2F77467286169c6c212cb9d1441f950c1e48dcd644',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__77%2F46%2F72%2F77467286169c6c212cb9d1441f950c1e48dcd644'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl043.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__e8/db/27/e8db27ee04706ed77e9b49c982d37dc3e76c9891',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 498972533,
#    'dateUploaded': '2025-03-04T22:43:09Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'b3bd38f24de295480d9453b9ba2ee849', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__e8%2Fdb%2F27%2Fe8db27ee04706ed77e9b49c982d37dc3e76c9891',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__e8%2Fdb%2F27%2Fe8db27ee04706ed77e9b49c982d37dc3e76c9891'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl044.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__66/9b/39/669b390dac93f2147a322939c42d72181b9ee39d',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 553150882,
#    'dateUploaded': '2025-03-04T22:46:01Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '92727afbbf6979c152ca88a84da8798a', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__66%2F9b%2F39%2F669b390dac93f2147a322939c42d72181b9ee39d',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__66%2F9b%2F39%2F669b390dac93f2147a322939c42d72181b9ee39d'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl049.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__be/6a/30/be6a30a8243cb635268eff3658a8fdf573e0d8b9',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 408098164,
#    'dateUploaded': '2025-03-04T22:47:58Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '803229d8f6cf3495a1bd3969da3007b7', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__be%2F6a%2F30%2Fbe6a30a8243cb635268eff3658a8fdf573e0d8b9',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__be%2F6a%2F30%2Fbe6a30a8243cb635268eff3658a8fdf573e0d8b9'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl051.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__50/c6/4c/50c64ccb7961e1623306ef70a86c71a20072353b',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 472610435,
#    'dateUploaded': '2025-03-04T22:50:19Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'fa41527e669b58d0a6e4a5137cf0fea5', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__50%2Fc6%2F4c%2F50c64ccb7961e1623306ef70a86c71a20072353b',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__50%2Fc6%2F4c%2F50c64ccb7961e1623306ef70a86c71a20072353b'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl059.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__66/40/62/664062ba4b6eddeed736b95ad70643391c5071bf',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 435695309,
#    'dateUploaded': '2025-03-04T22:52:34Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '30e5c63e011303fad7aad857ec57583f', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__66%2F40%2F62%2F664062ba4b6eddeed736b95ad70643391c5071bf',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__66%2F40%2F62%2F664062ba4b6eddeed736b95ad70643391c5071bf'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl060A.h5',
#    'title': '',
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__d7/91/ad/d791adc081301f7764daac24ee2f0ce68adc10c5',
#    'processed': False,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 511375787,
#    'dateUploaded': '2025-03-11T22:58:02Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': False,
#    'useForPreview': False,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'ce7b54a621de454f2eda3053eb6ff2e5', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__d7%2F91%2Fad%2Fd791adc081301f7764daac24ee2f0ce68adc10c5',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__d7%2F91%2Fad%2Fd791adc081301f7764daac24ee2f0ce68adc10c5'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl061.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__3f/d5/95/3fd595e1e61d5a96ea0e5664e860c45071286cd6',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 612052250,
#    'dateUploaded': '2025-03-04T22:56:43Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'a516a2ae65348ea0949061571a1e6c59', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__3f%2Fd5%2F95%2F3fd595e1e61d5a96ea0e5664e860c45071286cd6',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__3f%2Fd5%2F95%2F3fd595e1e61d5a96ea0e5664e860c45071286cd6'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl070.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__93/92/13/939213e93a6302bad06ac3aa407f574d79cd750b',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 477309545,
#    'dateUploaded': '2025-03-04T22:59:03Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '15c7eacb2975a7741050d73ae3d5f1ba', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__93%2F92%2F13%2F939213e93a6302bad06ac3aa407f574d79cd750b',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__93%2F92%2F13%2F939213e93a6302bad06ac3aa407f574d79cd750b'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl071.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__09/e4/52/09e452992d0d21b5674cb4908e237976a80f3ab8',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 511357311,
#    'dateUploaded': '2025-03-04T23:01:33Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '8791db4b09c793353beebd9d0b547156', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__09%2Fe4%2F52%2F09e452992d0d21b5674cb4908e237976a80f3ab8',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__09%2Fe4%2F52%2F09e452992d0d21b5674cb4908e237976a80f3ab8'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl074.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__eb/83/ef/eb83efd13ba61bb39bbc521be9860cf8076317ff',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 619792008,
#    'dateUploaded': '2025-03-04T23:04:42Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '3fdcbba36c22e20af62d42bfc2282adf', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__eb%2F83%2Fef%2Feb83efd13ba61bb39bbc521be9860cf8076317ff',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__eb%2F83%2Fef%2Feb83efd13ba61bb39bbc521be9860cf8076317ff'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl077.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__41/75/59/41755902ca8d370e7020acd003997d9ea3f2d1ae',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 523788361,
#    'dateUploaded': '2025-03-04T23:07:55Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'd3889b2541db74fc3c0acbafca158151', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__41%2F75%2F59%2F41755902ca8d370e7020acd003997d9ea3f2d1ae',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__41%2F75%2F59%2F41755902ca8d370e7020acd003997d9ea3f2d1ae'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl078.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__72/af/a2/72afa25c958881903f3a2c02e07dbb2f9d0ca2d2',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 512904762,
#    'dateUploaded': '2025-03-05T18:33:28Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'b817ed3a2f49ab13fed458b6a0c2f791', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__72%2Faf%2Fa2%2F72afa25c958881903f3a2c02e07dbb2f9d0ca2d2',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__72%2Faf%2Fa2%2F72afa25c958881903f3a2c02e07dbb2f9d0ca2d2'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl088.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__4f/7b/98/4f7b98d64aafebc5ac8217b0dfeb2bc4095e2ebf',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 462777184,
#    'dateUploaded': '2025-03-04T23:11:24Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '4399e93cb5c9e8f747301c14e4cdd843', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__4f%2F7b%2F98%2F4f7b98d64aafebc5ac8217b0dfeb2bc4095e2ebf',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__4f%2F7b%2F98%2F4f7b98d64aafebc5ac8217b0dfeb2bc4095e2ebf'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl090.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__5b/df/ed/5bdfedc22f1aaf406b6469242c23c2c061d3111a',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 487338115,
#    'dateUploaded': '2025-03-04T23:14:11Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '2ac3a7fe8d4e0d44b470577884c71e47', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__5b%2Fdf%2Fed%2F5bdfedc22f1aaf406b6469242c23c2c061d3111a',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__5b%2Fdf%2Fed%2F5bdfedc22f1aaf406b6469242c23c2c061d3111a'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl099.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__b6/e7/c9/b6e7c9d0553d92ce659146a582672b471a120483',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 432560781,
#    'dateUploaded': '2025-03-04T23:16:33Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '11d76243209c35c5c193a361bf361199', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__b6%2Fe7%2Fc9%2Fb6e7c9d0553d92ce659146a582672b471a120483',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__b6%2Fe7%2Fc9%2Fb6e7c9d0553d92ce659146a582672b471a120483'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl101.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__7d/7c/f6/7d7cf68e45e30298ead7b9076f377e7bdb3bca9b',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 444465030,
#    'dateUploaded': '2025-03-04T23:18:47Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '540dcb5019226ecd5e78a21ecf38f221', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__7d%2F7c%2Ff6%2F7d7cf68e45e30298ead7b9076f377e7bdb3bca9b',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__7d%2F7c%2Ff6%2F7d7cf68e45e30298ead7b9076f377e7bdb3bca9b'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl103.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__81/e6/85/81e685d5daf7cf866add6a4421746675deab500d',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 483446015,
#    'dateUploaded': '2025-03-04T23:21:05Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': '3d8506fd5dc16393310aa4ea76107394', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__81%2Fe6%2F85%2F81e685d5daf7cf866add6a4421746675deab500d',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__81%2Fe6%2F85%2F81e685d5daf7cf866add6a4421746675deab500d'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
#    'name': 'cl104.h5',
#    'title': None,
#    'contentType': 'application/x-hdf',
#    'contentEncoding': None,
#    'pathOnDisk': '__disk__45/95/47/459547fbe0c798688a77a03c4e971cf8426825c4',
#    'processed': None,
#    'processToken': None,
#    'imageWidth': None,
#    'imageHeight': None,
#    'size': 539268306,
#    'dateUploaded': '2025-03-04T23:23:41Z',
#    'uploadedBy': 'jpeacock@usgs.gov',
#    'originalMetadata': None,
#    'useForPreview': None,
#    'movedToS3': None,
#    's3Object': None,
#    'checksum': {'value': 'df62e89a5dd2608646c5ab54502df1ec', 'type': 'MD5'},
#    'url': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__45%2F95%2F47%2F459547fbe0c798688a77a03c4e971cf8426825c4',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/67a3b942d34e63325c2b7229?f=__disk__45%2F95%2F47%2F459547fbe0c798688a77a03c4e971cf8426825c4'},
#   {'cuid': None,
#    'key': None,
#    'bucket': None,
#    'published': None,
#    'node': None,
# ...
#     {'name': 'cl037.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 350268247,
#      'checksum': {'value': 'f8ca3562a71dc88950899b578e4e8b89', 'type': 'MD5'}},
#     {'name': 'cl043.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 498972533,
#      'checksum': {'value': 'b3bd38f24de295480d9453b9ba2ee849', 'type': 'MD5'}},
#     {'name': 'cl044.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 553150882,
#      'checksum': {'value': '92727afbbf6979c152ca88a84da8798a', 'type': 'MD5'}},
#     {'name': 'cl049.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 408098164,
#      'checksum': {'value': '803229d8f6cf3495a1bd3969da3007b7', 'type': 'MD5'}},
#     {'name': 'cl051.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 472610435,
#      'checksum': {'value': 'fa41527e669b58d0a6e4a5137cf0fea5', 'type': 'MD5'}},
#     {'name': 'cl059.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 435695309,
#      'checksum': {'value': '30e5c63e011303fad7aad857ec57583f', 'type': 'MD5'}},
#     {'name': 'cl060A.h5',
#      'title': '',
#      'contentType': 'application/x-hdf',
#      'size': 511375787,
#      'checksum': {'value': 'ce7b54a621de454f2eda3053eb6ff2e5', 'type': 'MD5'}},
#     {'name': 'cl061.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 612052250,
#      'checksum': {'value': 'a516a2ae65348ea0949061571a1e6c59', 'type': 'MD5'}},
#     {'name': 'cl070.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 477309545,
#      'checksum': {'value': '15c7eacb2975a7741050d73ae3d5f1ba', 'type': 'MD5'}},
#     {'name': 'cl071.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 511357311,
#      'checksum': {'value': '8791db4b09c793353beebd9d0b547156', 'type': 'MD5'}},
#     {'name': 'cl074.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 619792008,
#      'checksum': {'value': '3fdcbba36c22e20af62d42bfc2282adf', 'type': 'MD5'}},
#     {'name': 'cl077.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 523788361,
#      'checksum': {'value': 'd3889b2541db74fc3c0acbafca158151', 'type': 'MD5'}},
#     {'name': 'cl078.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 512904762,
#      'checksum': {'value': 'b817ed3a2f49ab13fed458b6a0c2f791', 'type': 'MD5'}},
#     {'name': 'cl088.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 462777184,
#      'checksum': {'value': '4399e93cb5c9e8f747301c14e4cdd843', 'type': 'MD5'}},
#     {'name': 'cl090.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 487338115,
#      'checksum': {'value': '2ac3a7fe8d4e0d44b470577884c71e47', 'type': 'MD5'}},
#     {'name': 'cl099.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 432560781,
#      'checksum': {'value': '11d76243209c35c5c193a361bf361199', 'type': 'MD5'}},
#     {'name': 'cl101.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 444465030,
#      'checksum': {'value': '540dcb5019226ecd5e78a21ecf38f221', 'type': 'MD5'}},
#     {'name': 'cl103.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 483446015,
#      'checksum': {'value': '3d8506fd5dc16393310aa4ea76107394', 'type': 'MD5'}},
#     {'name': 'cl104.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 539268306,
#      'checksum': {'value': 'df62e89a5dd2608646c5ab54502df1ec', 'type': 'MD5'}},
#     {'name': 'cl108.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 460226430,
#      'checksum': {'value': 'e77d51cb024cc458a1ca94908abcd257', 'type': 'MD5'}},
#     {'name': 'cl110.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 475789747,
#      'checksum': {'value': '5b940aa6f28561bf2486225bfa674b67', 'type': 'MD5'}},
#     {'name': 'cl111.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 559404758,
#      'checksum': {'value': '32e2bf2c7801ba25bb5fdebd31338d2b', 'type': 'MD5'}},
#     {'name': 'cl112.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 511403773,
#      'checksum': {'value': '0c398d1638201ccb7e52b7cdf2a6f5cd', 'type': 'MD5'}},
#     {'name': 'cl113.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 399833125,
#      'checksum': {'value': 'a5f8f737ae217f201a2f416cc76f908e', 'type': 'MD5'}},
#     {'name': 'cl126.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 468200572,
#      'checksum': {'value': '0003d1f820def9be2230b795aebd1805', 'type': 'MD5'}},
#     {'name': 'cl128.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 457130234,
#      'checksum': {'value': '2bc5746fd34a1441a294ab16cdd002c8', 'type': 'MD5'}},
#     {'name': 'cl129.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 469514046,
#      'checksum': {'value': 'e984805575d43fee570e09e038eff66b', 'type': 'MD5'}},
#     {'name': 'cl140.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 497425214,
#      'checksum': {'value': '6c287474188c5bafc86dd5ce20d9db9b', 'type': 'MD5'}},
#     {'name': 'cl141.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 457159041,
#      'checksum': {'value': 'c006087fe46dba8c4039f3e89078daab', 'type': 'MD5'}},
#     {'name': 'cl160.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 553150652,
#      'checksum': {'value': '3ae0b3bac6ccfc55b3c79a464a471fb1', 'type': 'MD5'}},
#     {'name': 'cl161.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 489685355,
#      'checksum': {'value': '2049ecf7c54c8faf166035453bf47e11', 'type': 'MD5'}},
#     {'name': 'cl162.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 475565075,
#      'checksum': {'value': '272fd394e8a9e1b3ef2b9dd70780e632', 'type': 'MD5'}},
#     {'name': 'cl163.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 455606867,
#      'checksum': {'value': '604bcb553618afec88ba7dbe6d1b56d0', 'type': 'MD5'}},
#     {'name': 'cl200.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 604311857,
#      'checksum': {'value': '72299d0c485b32b9cc312517477de2cb', 'type': 'MD5'}},
#     {'name': 'cl201.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 587712362,
#      'checksum': {'value': 'b57d9fe52fc5ecfc7968da0ed7d5f4d4', 'type': 'MD5'}},
#     {'name': 'cl203.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 509856192,
#      'checksum': {'value': 'a444576a9e9babebd8897ee7e5432af5', 'type': 'MD5'}},
#     {'name': 'cl204.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 475444396,
#      'checksum': {'value': '8832020e8628d5316b5db124bec5ac50', 'type': 'MD5'}},
#     {'name': 'cl205.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 462450201,
#      'checksum': {'value': 'aa782d91ff44837c03c7763a99bd83fb', 'type': 'MD5'}},
#     {'name': 'cl207.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 503478159,
#      'checksum': {'value': '87fb818f4af8d90d3cb7a8435584c6cc', 'type': 'MD5'}},
#     {'name': 'cl208.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 495354241,
#      'checksum': {'value': 'ac0f9bcaee0b09f79a8926c199b8735f', 'type': 'MD5'}},
#     {'name': 'cl211.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 474158104,
#      'checksum': {'value': 'c11dbccc70e33db6c9cab1b2f2065fde', 'type': 'MD5'}},
#     {'name': 'cl221.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 526837901,
#      'checksum': {'value': 'd9569dfc1e085432acf3c05132bbefb0', 'type': 'MD5'}},
#     {'name': 'cl230.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 464917524,
#      'checksum': {'value': '627d12453d2ccc8bf5bc00f63494f705', 'type': 'MD5'}},
#     {'name': 'cl302.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 463103762,
#      'checksum': {'value': '6a84e3f871eda8e5532c91acea2a2807', 'type': 'MD5'}},
#     {'name': 'cl303.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 408986439,
#      'checksum': {'value': '07b2e02ea5640c8ec71e9b0044f6adbb', 'type': 'MD5'}},
#     {'name': 'cl304.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 463074116,
#      'checksum': {'value': '2b90de46f032c0f7defb0c0b4a25c81b', 'type': 'MD5'}},
#     {'name': 'cl305.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 551277880,
#      'checksum': {'value': 'af299d8f8812651a87b14a5b5ddd8263', 'type': 'MD5'}},
#     {'name': 'cl306.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 490980341,
#      'checksum': {'value': '2d0bb14703498e1f36a093f4a354b083', 'type': 'MD5'}},
#     {'name': 'cl3101.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 582274197,
#      'checksum': {'value': '1303eca4d04d4042b30104060098b389', 'type': 'MD5'}},
#     {'name': 'cl3116.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 552947263,
#      'checksum': {'value': '1c29c4d18ec88edd18129866aaefa672', 'type': 'MD5'}},
#     {'name': 'cl3121.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 395311045,
#      'checksum': {'value': 'b767d1d752ed9901b77bd78eabe780b2', 'type': 'MD5'}},
#     {'name': 'cl3129.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 432115177,
#      'checksum': {'value': 'ada724ba10a4d2d8b9679ea402345bde', 'type': 'MD5'}},
#     {'name': 'cl321.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 395044641,
#      'checksum': {'value': '0667f1ba3638039a804affef3b8da819', 'type': 'MD5'}},
#     {'name': 'cl326.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 585352872,
#      'checksum': {'value': '589b85c1271c6a574572dd0972d6bdd5', 'type': 'MD5'}},
#     {'name': 'cl340.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 475499952,
#      'checksum': {'value': '023ab96582186fb347a38a9941260c24', 'type': 'MD5'}},
#     {'name': 'cl341.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 466170634,
#      'checksum': {'value': '6776e69f71052fc7f5687c15c2cbedc4', 'type': 'MD5'}},
#     {'name': 'cl355.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 466212233,
#      'checksum': {'value': 'dcd73278624cbaf6cc5c98e606fc02c8', 'type': 'MD5'}},
#     {'name': 'cl362.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 478600484,
#      'checksum': {'value': '9a839998d8426fbb577f86754f910848', 'type': 'MD5'}},
#     {'name': 'cl381.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 509556938,
#      'checksum': {'value': '39772373af4b6fca10925e2e6297a40d', 'type': 'MD5'}},
#     {'name': 'cl393.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 449142681,
#      'checksum': {'value': '43562305f8e4e0e5e011039ff35eca1c', 'type': 'MD5'}},
#     {'name': 'cl394.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 486335263,
#      'checksum': {'value': 'bbc198105195b8f6e7a9d87b2bfe24a1', 'type': 'MD5'}},
#     {'name': 'cl395.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 614806747,
#      'checksum': {'value': '8fd1a68a9c41542ca632497508fed032', 'type': 'MD5'}},
#     {'name': 'cl396.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 655077809,
#      'checksum': {'value': '349640573204ac4c03a7044b304a4e3e', 'type': 'MD5'}},
#     {'name': 'cl397.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 455357454,
#      'checksum': {'value': '3c29a97f64f2a1a1dbbf18ba4e40c305', 'type': 'MD5'}},
#     {'name': 'cl407.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 506393959,
#      'checksum': {'value': '62b4ef322b564b7789a73cdc6260d3d4', 'type': 'MD5'}},
#     {'name': 'cl408.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 489454178,
#      'checksum': {'value': '6379212583b9474543bb4634772e7e67', 'type': 'MD5'}},
#     {'name': 'cl409.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 473914347,
#      'checksum': {'value': 'ff9bbcd18c0a6c9bae90e3b078f042c6', 'type': 'MD5'}},
#     {'name': 'cl431.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 490984116,
#      'checksum': {'value': '9e5b70892ae3070300842402696eb6d2', 'type': 'MD5'}},
#     {'name': 'cl433.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 483532116,
#      'checksum': {'value': '93c2cb2c846f59e64a831824057f6161', 'type': 'MD5'}},
#     {'name': 'cl434.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 481654881,
#      'checksum': {'value': '92dc26a949dc0e0b633679a4894539c7', 'type': 'MD5'}},
#     {'name': 'cl435.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 969155356,
#      'checksum': {'value': '770416c773162a96dee5e2fc0443aae3', 'type': 'MD5'}},
#     {'name': 'cl436.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 497178773,
#      'checksum': {'value': '918e58a36ac3f40443a74db459c3302e', 'type': 'MD5'}},
#     {'name': 'cl455.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 572971558,
#      'checksum': {'value': '6301d3f9402cab65587aa42a6748b1ef', 'type': 'MD5'}},
#     {'name': 'cl461.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 506464601,
#      'checksum': {'value': '3ac18d79ebc672d2d119b8ec06a4068c', 'type': 'MD5'}},
#     {'name': 'cl463.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 514204861,
#      'checksum': {'value': '11b7da3846b73fbe262d3aa633f4a7b6', 'type': 'MD5'}},
#     {'name': 'cl471.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 619432302,
#      'checksum': {'value': '28a94c00d6dcf6432495d934d134e60a', 'type': 'MD5'}},
#     {'name': 'cl472.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 470818280,
#      'checksum': {'value': 'fc7fc4fbfb58555d98fdc6eef5e79109', 'type': 'MD5'}},
#     {'name': 'cl473.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 481696487,
#      'checksum': {'value': 'ab108c553df23690744afb68cc727720', 'type': 'MD5'}},
#     {'name': 'cl478.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 566748638,
#      'checksum': {'value': '8cc65ab5ed2aec7b5c43247e7394bca3', 'type': 'MD5'}},
#     {'name': 'cl479.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 506465356,
#      'checksum': {'value': '5b40e179f2e75c4ca2893c7d47950e8d', 'type': 'MD5'}},
#     {'name': 'cl484.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 503364678,
#      'checksum': {'value': 'f1d1ae48933151fccbd700793eab8c0f', 'type': 'MD5'}},
#     {'name': 'cl485.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 478601058,
#      'checksum': {'value': '4f4d290e733f441f559a2132ec193af7', 'type': 'MD5'}},
#     {'name': 'cl486.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 494080746,
#      'checksum': {'value': 'c301df4c7b6aa7632e7a007b1e4b95f4', 'type': 'MD5'}},
#     {'name': 'cl491.h5',
#      'title': None,
#      'contentType': 'application/x-hdf',
#      'size': 446047199,
#      'checksum': {'value': 'd1599f4919cbb5327702c14de5a4522a',
#       'type': 'MD5'}}]}],
#  'locked': False}

# %%
session.logout()
# Out:
# You have now been logged out.
